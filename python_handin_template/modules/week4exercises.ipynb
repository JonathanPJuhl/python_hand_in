# %%
#3 & #5 & #6
import exercise04 as e4
e4.ex04()
#6 Gives weird results for some reason
# Out:
# [51937, 75113, 78802, 61623, 51727, 39537, 43908, 53604, 55205, 64967, 3872]
# number of 65+ year olds: 59859
# non danish citizens: 12169396
